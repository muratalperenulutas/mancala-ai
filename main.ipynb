# %%
import sys
import numpy as np
from game_helper import GameHelper  
from replay_buffer import ReplayBuffer
from configs import Config
import random
import tensorflow as tf
from game.game import Game
from model_helper import ModelHelper
from model import Model
# Out:
# 2025-10-26 06:28:34.490137: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
version = tf.__version__
print("TensorFlow version:", version)
python_version = sys.version
print("Python version:", python_version)
# Out:
# TensorFlow version: 2.20.0
# Python version: 3.11.6 | packaged by conda-forge | (main, Oct  3 2023, 10:40:35) [GCC 12.3.0]

# %%
game = Game(verbose=False)
replay = ReplayBuffer()

# %%
model=Model.create_model()
Model.compile_model(model)
# Out:
# /opt/conda/lib/python3.11/site-packages/keras/src/layers/core/dense.py:92: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2025-10-26 06:28:36.601357: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │         1,344 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │         8,320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 6)              │           390 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 18,310 (71.52 KB)
#  Trainable params: 18,310 (71.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
Model.train_model(model=model, game=game, replay=replay)
GameHelper.play_against_model(model=model, game=game)
# Out:
# Game 1 started
# Game 11 started
# Game 21 started
# Game 31 started
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 Model.train_model(model=model, game=game, replay=replay)
#       2 GameHelper.play_against_model(model=model, board=game.get_board())
#
# File ~/model.py:149, in Model.train_model(model, game, replay, game_count, input_features_size, epsilon_start, epsilon_end, epsilon_decay_steps, gamma, K, debug)
#     145 game.play(board_index)
#     147 reward = GameHelper.get_move_score(game)
# --> 149 next_features = ModelHelper.build_features_from_state(game.get_board(), player, game.game_finish)
#     150 normalized_next_state = ModelHelper.normalize_single_fixed(next_features)
#     152 legal_next_actions = game.get_playable_pits()
#
# File ~/model_helper.py:44, in ModelHelper.build_features_from_state(board14, player, game_finish)
#      35 can_board = GameHelper.canonicalize_board(board14, player)
#      36 extras = [
#      37     can_board[7] - can_board[0],
#      38     sum(can_board[0:7]),
#    (...)
#      41     sum(1 for i in can_board[7:14] if i == 0),
#      42 ]
# ---> 44 features = np.array(can_board + [int(game_finish)] + list(extras), dtype=np.float32)
#      45 return features
#
# KeyboardInterrupt:
