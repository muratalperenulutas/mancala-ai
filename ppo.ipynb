# %%
from game_helper import GameHelper
from game.game import Game
from configs import Config
from model_helper import ModelHelper
from ppo_trainer import build_actor_critic_model
from ppo_trainer import PPOTrainer
# Out:
# 2025-10-26 18:22:10.949221: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
game = Game()
game.reset()

ppo_model = build_actor_critic_model(input_dim=Config.INPUT_FEATURES, hidden=Config.PPO_HIDDEN_SIZE)
ppo_model.summary()


print("\nStarting PPO training...")

trainer = PPOTrainer(ppo_model)
metrics = trainer.train_ppo(game, total_timesteps=Config.PPO_TOTAL_TIMESTEPS, 
                            n_steps=Config.PPO_N_STEPS, log_interval=1)

print("\nTraining completed successfully!")
print(f"Final metrics: {metrics}")
# Out:
# 2025-10-26 18:22:12.957886: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ state (InputLayer)  │ (None, 20)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared1 (Dense)     │ (None, 128)       │      2,688 │ state[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared2 (Dense)     │ (None, 128)       │     16,512 │ shared1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logits (Dense)      │ (None, 6)         │        774 │ shared2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ value (Dense)       │ (None, 1)         │        129 │ shared2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,103 (78.53 KB)
#  Trainable params: 20,103 (78.53 KB)
#  Non-trainable params: 0 (0.00 B)
# Starting PPO training...
#
# Starting PPO Training...
# Total timesteps: 200000
# Rollout steps: 2048
# ================================================================================
#
# ================================================================================
# Iteration: 1 | Timesteps: 2048/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 34.715
#   Avg Episode Length: 28.5
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  0.0086
#   Value Loss:   63.8812
#   Entropy:      1.2541
#
# Training Metrics:
#   Grad Norm:    36.865
#   Clip Fraction: 0.278
#   Approx KL:    0.0171
#
# Action Masking:
#   Illegal Before Mask: 0.290
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 2 | Timesteps: 4096/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.400
#   Avg Episode Length: 29.7
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  0.0015
#   Value Loss:   23.0833
#   Entropy:      1.2583
#
# Training Metrics:
#   Grad Norm:    30.791
#   Clip Fraction: 0.061
#   Approx KL:    0.0059
#
# Action Masking:
#   Illegal Before Mask: 0.347
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 3 | Timesteps: 6144/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 34.703
#   Avg Episode Length: 29.3
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0015
#   Value Loss:   11.0277
#   Entropy:      1.2028
#
# Training Metrics:
#   Grad Norm:    16.120
#   Clip Fraction: 0.066
#   Approx KL:    0.0056
#
# Action Masking:
#   Illegal Before Mask: 0.404
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 4 | Timesteps: 8192/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 33.573
#   Avg Episode Length: 27.2
#   Episodes Completed: 75
#
# Loss Metrics:
#   Policy Loss:  -0.0016
#   Value Loss:   5.8044
#   Entropy:      1.1823
#
# Training Metrics:
#   Grad Norm:    9.331
#   Clip Fraction: 0.070
#   Approx KL:    0.0058
#
# Action Masking:
#   Illegal Before Mask: 0.415
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 5 | Timesteps: 10240/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 34.662
#   Avg Episode Length: 28.6
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0042
#   Value Loss:   4.2937
#   Entropy:      1.1561
#
# Training Metrics:
#   Grad Norm:    8.286
#   Clip Fraction: 0.124
#   Approx KL:    0.0121
#
# Action Masking:
#   Illegal Before Mask: 0.451
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 6 | Timesteps: 12288/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.247
#   Avg Episode Length: 28.6
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0029
#   Value Loss:   3.5752
#   Entropy:      1.1910
#
# Training Metrics:
#   Grad Norm:    8.337
#   Clip Fraction: 0.077
#   Approx KL:    0.0045
#
# Action Masking:
#   Illegal Before Mask: 0.473
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 7 | Timesteps: 14336/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.578
#   Avg Episode Length: 28.7
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0045
#   Value Loss:   3.1079
#   Entropy:      1.1650
#
# Training Metrics:
#   Grad Norm:    7.667
#   Clip Fraction: 0.102
#   Approx KL:    0.0072
#
# Action Masking:
#   Illegal Before Mask: 0.478
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 8 | Timesteps: 16384/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.724
#   Avg Episode Length: 29.2
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0041
#   Value Loss:   3.5134
#   Entropy:      1.1123
#
# Training Metrics:
#   Grad Norm:    7.380
#   Clip Fraction: 0.128
#   Approx KL:    0.0118
#
# Action Masking:
#   Illegal Before Mask: 0.494
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 9 | Timesteps: 18432/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.857
#   Avg Episode Length: 31.0
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  -0.0018
#   Value Loss:   3.8693
#   Entropy:      1.0751
#
# Training Metrics:
#   Grad Norm:    8.328
#   Clip Fraction: 0.080
#   Approx KL:    0.0058
#
# Action Masking:
#   Illegal Before Mask: 0.526
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 10 | Timesteps: 20480/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.930
#   Avg Episode Length: 30.0
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  -0.0012
#   Value Loss:   2.5666
#   Entropy:      1.0172
#
# Training Metrics:
#   Grad Norm:    6.783
#   Clip Fraction: 0.059
#   Approx KL:    0.0017
#
# Action Masking:
#   Illegal Before Mask: 0.559
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 11 | Timesteps: 22528/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.152
#   Avg Episode Length: 30.5
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  -0.0037
#   Value Loss:   3.7204
#   Entropy:      0.9398
#
# Training Metrics:
#   Grad Norm:    8.334
#   Clip Fraction: 0.080
#   Approx KL:    0.0051
#
# Action Masking:
#   Illegal Before Mask: 0.573
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 12 | Timesteps: 24576/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.653
#   Avg Episode Length: 32.2
#   Episodes Completed: 63
#
# Loss Metrics:
#   Policy Loss:  0.0007
#   Value Loss:   2.6748
#   Entropy:      0.9087
#
# Training Metrics:
#   Grad Norm:    6.641
#   Clip Fraction: 0.056
#   Approx KL:    0.0059
#
# Action Masking:
#   Illegal Before Mask: 0.564
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 13 | Timesteps: 26624/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.237
#   Avg Episode Length: 30.5
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  0.0015
#   Value Loss:   3.5495
#   Entropy:      0.9082
#
# Training Metrics:
#   Grad Norm:    8.062
#   Clip Fraction: 0.032
#   Approx KL:    0.0031
#
# Action Masking:
#   Illegal Before Mask: 0.584
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 14 | Timesteps: 28672/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.258
#   Avg Episode Length: 31.0
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  -0.0025
#   Value Loss:   3.2404
#   Entropy:      0.8311
#
# Training Metrics:
#   Grad Norm:    7.723
#   Clip Fraction: 0.051
#   Approx KL:    0.0032
#
# Action Masking:
#   Illegal Before Mask: 0.587
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 15 | Timesteps: 30720/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.064
#   Avg Episode Length: 30.1
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  -0.0017
#   Value Loss:   3.6894
#   Entropy:      0.7900
#
# Training Metrics:
#   Grad Norm:    8.318
#   Clip Fraction: 0.092
#   Approx KL:    0.0048
#
# Action Masking:
#   Illegal Before Mask: 0.591
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 16 | Timesteps: 32768/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.991
#   Avg Episode Length: 29.5
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0027
#   Value Loss:   3.8289
#   Entropy:      0.8164
#
# Training Metrics:
#   Grad Norm:    7.583
#   Clip Fraction: 0.089
#   Approx KL:    0.0085
#
# Action Masking:
#   Illegal Before Mask: 0.589
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 17 | Timesteps: 34816/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.278
#   Avg Episode Length: 27.9
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  0.0003
#   Value Loss:   3.8346
#   Entropy:      0.7866
#
# Training Metrics:
#   Grad Norm:    8.274
#   Clip Fraction: 0.047
#   Approx KL:    0.0027
#
# Action Masking:
#   Illegal Before Mask: 0.600
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 18 | Timesteps: 36864/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.373
#   Avg Episode Length: 30.7
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  0.0002
#   Value Loss:   2.9984
#   Entropy:      0.8165
#
# Training Metrics:
#   Grad Norm:    7.727
#   Clip Fraction: 0.042
#   Approx KL:    0.0028
#
# Action Masking:
#   Illegal Before Mask: 0.583
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 19 | Timesteps: 38912/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.080
#   Avg Episode Length: 27.6
#   Episodes Completed: 74
#
# Loss Metrics:
#   Policy Loss:  -0.0036
#   Value Loss:   4.6352
#   Entropy:      0.7609
#
# Training Metrics:
#   Grad Norm:    8.300
#   Clip Fraction: 0.049
#   Approx KL:    0.0053
#
# Action Masking:
#   Illegal Before Mask: 0.565
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 20 | Timesteps: 40960/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.289
#   Avg Episode Length: 30.4
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  0.0002
#   Value Loss:   2.2237
#   Entropy:      0.7084
#
# Training Metrics:
#   Grad Norm:    6.268
#   Clip Fraction: 0.040
#   Approx KL:    0.0032
#
# Action Masking:
#   Illegal Before Mask: 0.599
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 21 | Timesteps: 43008/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.966
#   Avg Episode Length: 30.7
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  0.0011
#   Value Loss:   4.6414
#   Entropy:      0.7094
#
# Training Metrics:
#   Grad Norm:    8.515
#   Clip Fraction: 0.056
#   Approx KL:    0.0042
#
# Action Masking:
#   Illegal Before Mask: 0.608
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 22 | Timesteps: 45056/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.339
#   Avg Episode Length: 28.3
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0019
#   Value Loss:   3.4878
#   Entropy:      0.6908
#
# Training Metrics:
#   Grad Norm:    7.690
#   Clip Fraction: 0.046
#   Approx KL:    0.0036
#
# Action Masking:
#   Illegal Before Mask: 0.587
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 23 | Timesteps: 47104/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.535
#   Avg Episode Length: 28.7
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0001
#   Value Loss:   3.2495
#   Entropy:      0.6798
#
# Training Metrics:
#   Grad Norm:    8.654
#   Clip Fraction: 0.041
#   Approx KL:    0.0044
#
# Action Masking:
#   Illegal Before Mask: 0.591
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 24 | Timesteps: 49152/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 38.131
#   Avg Episode Length: 31.9
#   Episodes Completed: 64
#
# Loss Metrics:
#   Policy Loss:  -0.0006
#   Value Loss:   2.3961
#   Entropy:      0.6847
#
# Training Metrics:
#   Grad Norm:    7.388
#   Clip Fraction: 0.049
#   Approx KL:    0.0048
#
# Action Masking:
#   Illegal Before Mask: 0.610
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 25 | Timesteps: 51200/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.549
#   Avg Episode Length: 31.0
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  -0.0008
#   Value Loss:   3.0419
#   Entropy:      0.6335
#
# Training Metrics:
#   Grad Norm:    7.524
#   Clip Fraction: 0.037
#   Approx KL:    0.0028
#
# Action Masking:
#   Illegal Before Mask: 0.616
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 26 | Timesteps: 53248/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.647
#   Avg Episode Length: 28.8
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  0.0003
#   Value Loss:   3.0676
#   Entropy:      0.6011
#
# Training Metrics:
#   Grad Norm:    8.492
#   Clip Fraction: 0.023
#   Approx KL:    0.0006
#
# Action Masking:
#   Illegal Before Mask: 0.612
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 27 | Timesteps: 55296/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.625
#   Avg Episode Length: 31.2
#   Episodes Completed: 64
#
# Loss Metrics:
#   Policy Loss:  -0.0009
#   Value Loss:   2.8996
#   Entropy:      0.6242
#
# Training Metrics:
#   Grad Norm:    7.534
#   Clip Fraction: 0.022
#   Approx KL:    0.0027
#
# Action Masking:
#   Illegal Before Mask: 0.603
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 28 | Timesteps: 57344/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.027
#   Avg Episode Length: 30.1
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  -0.0016
#   Value Loss:   3.9380
#   Entropy:      0.6237
#
# Training Metrics:
#   Grad Norm:    9.127
#   Clip Fraction: 0.054
#   Approx KL:    0.0061
#
# Action Masking:
#   Illegal Before Mask: 0.607
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 29 | Timesteps: 59392/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.982
#   Avg Episode Length: 29.5
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0023
#   Value Loss:   3.5978
#   Entropy:      0.6008
#
# Training Metrics:
#   Grad Norm:    8.406
#   Clip Fraction: 0.059
#   Approx KL:    0.0019
#
# Action Masking:
#   Illegal Before Mask: 0.611
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 30 | Timesteps: 61440/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.192
#   Avg Episode Length: 29.2
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0009
#   Value Loss:   2.2900
#   Entropy:      0.5984
#
# Training Metrics:
#   Grad Norm:    7.774
#   Clip Fraction: 0.041
#   Approx KL:    0.0043
#
# Action Masking:
#   Illegal Before Mask: 0.604
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 31 | Timesteps: 63488/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.260
#   Avg Episode Length: 27.9
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0015
#   Value Loss:   4.0893
#   Entropy:      0.6198
#
# Training Metrics:
#   Grad Norm:    9.309
#   Clip Fraction: 0.041
#   Approx KL:    0.0037
#
# Action Masking:
#   Illegal Before Mask: 0.607
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 32 | Timesteps: 65536/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.995
#   Avg Episode Length: 27.2
#   Episodes Completed: 74
#
# Loss Metrics:
#   Policy Loss:  -0.0015
#   Value Loss:   3.5819
#   Entropy:      0.6162
#
# Training Metrics:
#   Grad Norm:    8.535
#   Clip Fraction: 0.039
#   Approx KL:    0.0039
#
# Action Masking:
#   Illegal Before Mask: 0.589
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 33 | Timesteps: 67584/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.691
#   Avg Episode Length: 25.4
#   Episodes Completed: 80
#
# Loss Metrics:
#   Policy Loss:  -0.0004
#   Value Loss:   1.8315
#   Entropy:      0.5800
#
# Training Metrics:
#   Grad Norm:    6.285
#   Clip Fraction: 0.043
#   Approx KL:    0.0029
#
# Action Masking:
#   Illegal Before Mask: 0.596
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 34 | Timesteps: 69632/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.993
#   Avg Episode Length: 29.1
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0021
#   Value Loss:   2.5737
#   Entropy:      0.6000
#
# Training Metrics:
#   Grad Norm:    7.720
#   Clip Fraction: 0.052
#   Approx KL:    0.0050
#
# Action Masking:
#   Illegal Before Mask: 0.625
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 35 | Timesteps: 71680/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.679
#   Avg Episode Length: 30.4
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  -0.0008
#   Value Loss:   3.2198
#   Entropy:      0.5846
#
# Training Metrics:
#   Grad Norm:    8.019
#   Clip Fraction: 0.041
#   Approx KL:    0.0044
#
# Action Masking:
#   Illegal Before Mask: 0.617
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 36 | Timesteps: 73728/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.300
#   Avg Episode Length: 29.2
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0002
#   Value Loss:   2.1137
#   Entropy:      0.5694
#
# Training Metrics:
#   Grad Norm:    7.161
#   Clip Fraction: 0.061
#   Approx KL:    0.0067
#
# Action Masking:
#   Illegal Before Mask: 0.625
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 37 | Timesteps: 75776/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.986
#   Avg Episode Length: 29.3
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0001
#   Value Loss:   3.0282
#   Entropy:      0.5650
#
# Training Metrics:
#   Grad Norm:    8.768
#   Clip Fraction: 0.034
#   Approx KL:    0.0027
#
# Action Masking:
#   Illegal Before Mask: 0.627
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 38 | Timesteps: 77824/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.090
#   Avg Episode Length: 29.1
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  0.0015
#   Value Loss:   2.0123
#   Entropy:      0.5628
#
# Training Metrics:
#   Grad Norm:    6.445
#   Clip Fraction: 0.023
#   Approx KL:    0.0039
#
# Action Masking:
#   Illegal Before Mask: 0.635
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 39 | Timesteps: 79872/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.366
#   Avg Episode Length: 30.4
#   Episodes Completed: 67
#
# Loss Metrics:
#   Policy Loss:  -0.0006
#   Value Loss:   2.7468
#   Entropy:      0.5697
#
# Training Metrics:
#   Grad Norm:    7.936
#   Clip Fraction: 0.032
#   Approx KL:    0.0033
#
# Action Masking:
#   Illegal Before Mask: 0.641
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 40 | Timesteps: 81920/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.005
#   Avg Episode Length: 28.8
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0021
#   Value Loss:   2.3757
#   Entropy:      0.5290
#
# Training Metrics:
#   Grad Norm:    7.574
#   Clip Fraction: 0.039
#   Approx KL:    0.0009
#
# Action Masking:
#   Illegal Before Mask: 0.639
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 41 | Timesteps: 83968/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.997
#   Avg Episode Length: 28.7
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0009
#   Value Loss:   1.3248
#   Entropy:      0.5638
#
# Training Metrics:
#   Grad Norm:    6.078
#   Clip Fraction: 0.041
#   Approx KL:    0.0020
#
# Action Masking:
#   Illegal Before Mask: 0.648
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 42 | Timesteps: 86016/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.184
#   Avg Episode Length: 26.9
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  0.0015
#   Value Loss:   2.4194
#   Entropy:      0.5518
#
# Training Metrics:
#   Grad Norm:    7.247
#   Clip Fraction: 0.030
#   Approx KL:    0.0035
#
# Action Masking:
#   Illegal Before Mask: 0.639
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 43 | Timesteps: 88064/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.089
#   Avg Episode Length: 28.7
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  0.0006
#   Value Loss:   1.8530
#   Entropy:      0.5342
#
# Training Metrics:
#   Grad Norm:    6.323
#   Clip Fraction: 0.043
#   Approx KL:    0.0027
#
# Action Masking:
#   Illegal Before Mask: 0.643
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 44 | Timesteps: 90112/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.712
#   Avg Episode Length: 28.1
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0023
#   Value Loss:   2.5131
#   Entropy:      0.5530
#
# Training Metrics:
#   Grad Norm:    7.494
#   Clip Fraction: 0.046
#   Approx KL:    0.0033
#
# Action Masking:
#   Illegal Before Mask: 0.639
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 45 | Timesteps: 92160/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.230
#   Avg Episode Length: 26.9
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  -0.0011
#   Value Loss:   1.7749
#   Entropy:      0.5280
#
# Training Metrics:
#   Grad Norm:    6.286
#   Clip Fraction: 0.052
#   Approx KL:    0.0058
#
# Action Masking:
#   Illegal Before Mask: 0.607
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 46 | Timesteps: 94208/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.685
#   Avg Episode Length: 27.9
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0031
#   Value Loss:   1.6979
#   Entropy:      0.5210
#
# Training Metrics:
#   Grad Norm:    6.721
#   Clip Fraction: 0.077
#   Approx KL:    0.0052
#
# Action Masking:
#   Illegal Before Mask: 0.639
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 47 | Timesteps: 96256/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.889
#   Avg Episode Length: 25.6
#   Episodes Completed: 79
#
# Loss Metrics:
#   Policy Loss:  -0.0007
#   Value Loss:   1.2870
#   Entropy:      0.5008
#
# Training Metrics:
#   Grad Norm:    5.330
#   Clip Fraction: 0.051
#   Approx KL:    0.0018
#
# Action Masking:
#   Illegal Before Mask: 0.629
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 48 | Timesteps: 98304/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.431
#   Avg Episode Length: 26.9
#   Episodes Completed: 75
#
# Loss Metrics:
#   Policy Loss:  0.0004
#   Value Loss:   1.2171
#   Entropy:      0.5295
#
# Training Metrics:
#   Grad Norm:    5.353
#   Clip Fraction: 0.026
#   Approx KL:    0.0046
#
# Action Masking:
#   Illegal Before Mask: 0.650
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 49 | Timesteps: 100352/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.185
#   Avg Episode Length: 26.4
#   Episodes Completed: 77
#
# Loss Metrics:
#   Policy Loss:  -0.0023
#   Value Loss:   1.2273
#   Entropy:      0.5119
#
# Training Metrics:
#   Grad Norm:    5.823
#   Clip Fraction: 0.028
#   Approx KL:    0.0008
#
# Action Masking:
#   Illegal Before Mask: 0.637
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 50 | Timesteps: 102400/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.961
#   Avg Episode Length: 28.8
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0028
#   Value Loss:   2.0095
#   Entropy:      0.4784
#
# Training Metrics:
#   Grad Norm:    6.899
#   Clip Fraction: 0.040
#   Approx KL:    0.0051
#
# Action Masking:
#   Illegal Before Mask: 0.635
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 51 | Timesteps: 104448/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.000
#   Avg Episode Length: 28.6
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  0.0001
#   Value Loss:   1.9126
#   Entropy:      0.4930
#
# Training Metrics:
#   Grad Norm:    6.812
#   Clip Fraction: 0.012
#   Approx KL:    0.0010
#
# Action Masking:
#   Illegal Before Mask: 0.654
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 52 | Timesteps: 106496/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.556
#   Avg Episode Length: 27.7
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0005
#   Value Loss:   2.2464
#   Entropy:      0.4875
#
# Training Metrics:
#   Grad Norm:    6.428
#   Clip Fraction: 0.043
#   Approx KL:    0.0020
#
# Action Masking:
#   Illegal Before Mask: 0.647
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 53 | Timesteps: 108544/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.510
#   Avg Episode Length: 27.8
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0015
#   Value Loss:   1.6698
#   Entropy:      0.4687
#
# Training Metrics:
#   Grad Norm:    6.654
#   Clip Fraction: 0.041
#   Approx KL:    0.0037
#
# Action Masking:
#   Illegal Before Mask: 0.657
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 54 | Timesteps: 110592/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.296
#   Avg Episode Length: 26.7
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  -0.0014
#   Value Loss:   1.8002
#   Entropy:      0.4637
#
# Training Metrics:
#   Grad Norm:    7.009
#   Clip Fraction: 0.042
#   Approx KL:    0.0045
#
# Action Masking:
#   Illegal Before Mask: 0.641
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 55 | Timesteps: 112640/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.069
#   Avg Episode Length: 26.4
#   Episodes Completed: 77
#
# Loss Metrics:
#   Policy Loss:  0.0000
#   Value Loss:   1.4009
#   Entropy:      0.5119
#
# Training Metrics:
#   Grad Norm:    5.610
#   Clip Fraction: 0.047
#   Approx KL:    0.0025
#
# Action Masking:
#   Illegal Before Mask: 0.650
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 56 | Timesteps: 114688/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.978
#   Avg Episode Length: 26.8
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  -0.0010
#   Value Loss:   2.4166
#   Entropy:      0.5405
#
# Training Metrics:
#   Grad Norm:    7.852
#   Clip Fraction: 0.046
#   Approx KL:    0.0025
#
# Action Masking:
#   Illegal Before Mask: 0.641
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 57 | Timesteps: 116736/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.826
#   Avg Episode Length: 28.2
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0014
#   Value Loss:   1.6589
#   Entropy:      0.5513
#
# Training Metrics:
#   Grad Norm:    6.838
#   Clip Fraction: 0.033
#   Approx KL:    0.0031
#
# Action Masking:
#   Illegal Before Mask: 0.659
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 58 | Timesteps: 118784/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.846
#   Avg Episode Length: 28.1
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0028
#   Value Loss:   1.4945
#   Entropy:      0.5332
#
# Training Metrics:
#   Grad Norm:    6.357
#   Clip Fraction: 0.075
#   Approx KL:    0.0049
#
# Action Masking:
#   Illegal Before Mask: 0.659
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 59 | Timesteps: 120832/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.771
#   Avg Episode Length: 25.7
#   Episodes Completed: 79
#
# Loss Metrics:
#   Policy Loss:  -0.0002
#   Value Loss:   2.0686
#   Entropy:      0.5578
#
# Training Metrics:
#   Grad Norm:    7.543
#   Clip Fraction: 0.024
#   Approx KL:    0.0030
#
# Action Masking:
#   Illegal Before Mask: 0.646
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 60 | Timesteps: 122880/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.935
#   Avg Episode Length: 28.2
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0002
#   Value Loss:   0.8794
#   Entropy:      0.5784
#
# Training Metrics:
#   Grad Norm:    5.165
#   Clip Fraction: 0.057
#   Approx KL:    0.0058
#
# Action Masking:
#   Illegal Before Mask: 0.659
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 61 | Timesteps: 124928/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.044
#   Avg Episode Length: 27.8
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0011
#   Value Loss:   3.0099
#   Entropy:      0.5636
#
# Training Metrics:
#   Grad Norm:    9.315
#   Clip Fraction: 0.016
#   Approx KL:    0.0015
#
# Action Masking:
#   Illegal Before Mask: 0.644
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 62 | Timesteps: 126976/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.845
#   Avg Episode Length: 25.9
#   Episodes Completed: 79
#
# Loss Metrics:
#   Policy Loss:  -0.0002
#   Value Loss:   1.5872
#   Entropy:      0.5840
#
# Training Metrics:
#   Grad Norm:    6.850
#   Clip Fraction: 0.092
#   Approx KL:    0.0053
#
# Action Masking:
#   Illegal Before Mask: 0.629
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 63 | Timesteps: 129024/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.289
#   Avg Episode Length: 27.2
#   Episodes Completed: 75
#
# Loss Metrics:
#   Policy Loss:  -0.0025
#   Value Loss:   1.8673
#   Entropy:      0.5684
#
# Training Metrics:
#   Grad Norm:    7.014
#   Clip Fraction: 0.064
#   Approx KL:    0.0047
#
# Action Masking:
#   Illegal Before Mask: 0.641
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 64 | Timesteps: 131072/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.401
#   Avg Episode Length: 27.7
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0014
#   Value Loss:   2.1769
#   Entropy:      0.5340
#
# Training Metrics:
#   Grad Norm:    7.285
#   Clip Fraction: 0.048
#   Approx KL:    0.0055
#
# Action Masking:
#   Illegal Before Mask: 0.626
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 65 | Timesteps: 133120/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.411
#   Avg Episode Length: 29.6
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  0.0010
#   Value Loss:   1.6177
#   Entropy:      0.5526
#
# Training Metrics:
#   Grad Norm:    6.134
#   Clip Fraction: 0.057
#   Approx KL:    0.0044
#
# Action Masking:
#   Illegal Before Mask: 0.654
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 66 | Timesteps: 135168/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.124
#   Avg Episode Length: 29.7
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0023
#   Value Loss:   2.2224
#   Entropy:      0.4855
#
# Training Metrics:
#   Grad Norm:    6.761
#   Clip Fraction: 0.043
#   Approx KL:    0.0047
#
# Action Masking:
#   Illegal Before Mask: 0.621
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 67 | Timesteps: 137216/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.273
#   Avg Episode Length: 26.6
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  -0.0011
#   Value Loss:   0.7547
#   Entropy:      0.4810
#
# Training Metrics:
#   Grad Norm:    4.721
#   Clip Fraction: 0.024
#   Approx KL:    0.0021
#
# Action Masking:
#   Illegal Before Mask: 0.641
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 68 | Timesteps: 139264/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.932
#   Avg Episode Length: 26.8
#   Episodes Completed: 76
#
# Loss Metrics:
#   Policy Loss:  -0.0003
#   Value Loss:   2.6285
#   Entropy:      0.5001
#
# Training Metrics:
#   Grad Norm:    8.987
#   Clip Fraction: 0.009
#   Approx KL:    0.0017
#
# Action Masking:
#   Illegal Before Mask: 0.634
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 69 | Timesteps: 141312/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.826
#   Avg Episode Length: 28.8
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0014
#   Value Loss:   2.0519
#   Entropy:      0.4741
#
# Training Metrics:
#   Grad Norm:    7.620
#   Clip Fraction: 0.023
#   Approx KL:    0.0028
#
# Action Masking:
#   Illegal Before Mask: 0.634
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 70 | Timesteps: 143360/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.563
#   Avg Episode Length: 25.2
#   Episodes Completed: 81
#
# Loss Metrics:
#   Policy Loss:  -0.0018
#   Value Loss:   2.1377
#   Entropy:      0.4652
#
# Training Metrics:
#   Grad Norm:    7.600
#   Clip Fraction: 0.043
#   Approx KL:    0.0041
#
# Action Masking:
#   Illegal Before Mask: 0.638
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 71 | Timesteps: 145408/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.293
#   Avg Episode Length: 29.1
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0013
#   Value Loss:   1.0760
#   Entropy:      0.4621
#
# Training Metrics:
#   Grad Norm:    5.392
#   Clip Fraction: 0.026
#   Approx KL:    0.0002
#
# Action Masking:
#   Illegal Before Mask: 0.638
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 72 | Timesteps: 147456/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.679
#   Avg Episode Length: 28.2
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0001
#   Value Loss:   2.3049
#   Entropy:      0.5066
#
# Training Metrics:
#   Grad Norm:    7.144
#   Clip Fraction: 0.028
#   Approx KL:    0.0015
#
# Action Masking:
#   Illegal Before Mask: 0.631
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 73 | Timesteps: 149504/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.816
#   Avg Episode Length: 28.8
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0008
#   Value Loss:   2.4991
#   Entropy:      0.5392
#
# Training Metrics:
#   Grad Norm:    7.902
#   Clip Fraction: 0.048
#   Approx KL:    0.0011
#
# Action Masking:
#   Illegal Before Mask: 0.622
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 74 | Timesteps: 151552/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.775
#   Avg Episode Length: 28.4
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0022
#   Value Loss:   2.5146
#   Entropy:      0.5746
#
# Training Metrics:
#   Grad Norm:    7.980
#   Clip Fraction: 0.054
#   Approx KL:    0.0084
#
# Action Masking:
#   Illegal Before Mask: 0.617
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 75 | Timesteps: 153600/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.878
#   Avg Episode Length: 28.7
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  0.0001
#   Value Loss:   1.8864
#   Entropy:      0.5759
#
# Training Metrics:
#   Grad Norm:    7.171
#   Clip Fraction: 0.060
#   Approx KL:    0.0046
#
# Action Masking:
#   Illegal Before Mask: 0.576
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 76 | Timesteps: 155648/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 35.557
#   Avg Episode Length: 25.6
#   Episodes Completed: 79
#
# Loss Metrics:
#   Policy Loss:  -0.0009
#   Value Loss:   2.1148
#   Entropy:      0.5619
#
# Training Metrics:
#   Grad Norm:    7.123
#   Clip Fraction: 0.030
#   Approx KL:    0.0040
#
# Action Masking:
#   Illegal Before Mask: 0.585
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 77 | Timesteps: 157696/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.591
#   Avg Episode Length: 27.8
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0017
#   Value Loss:   2.1898
#   Entropy:      0.5341
#
# Training Metrics:
#   Grad Norm:    7.912
#   Clip Fraction: 0.046
#   Approx KL:    0.0039
#
# Action Masking:
#   Illegal Before Mask: 0.615
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 78 | Timesteps: 159744/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.786
#   Avg Episode Length: 28.4
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0011
#   Value Loss:   1.5170
#   Entropy:      0.5325
#
# Training Metrics:
#   Grad Norm:    6.454
#   Clip Fraction: 0.014
#   Approx KL:    0.0017
#
# Action Masking:
#   Illegal Before Mask: 0.610
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 79 | Timesteps: 161792/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.204
#   Avg Episode Length: 27.3
#   Episodes Completed: 75
#
# Loss Metrics:
#   Policy Loss:  -0.0012
#   Value Loss:   3.0593
#   Entropy:      0.5193
#
# Training Metrics:
#   Grad Norm:    9.522
#   Clip Fraction: 0.023
#   Approx KL:    0.0026
#
# Action Masking:
#   Illegal Before Mask: 0.592
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 80 | Timesteps: 163840/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.691
#   Avg Episode Length: 28.1
#   Episodes Completed: 72
#
# Loss Metrics:
#   Policy Loss:  -0.0014
#   Value Loss:   1.5815
#   Entropy:      0.5263
#
# Training Metrics:
#   Grad Norm:    6.241
#   Clip Fraction: 0.045
#   Approx KL:    0.0095
#
# Action Masking:
#   Illegal Before Mask: 0.613
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 81 | Timesteps: 165888/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.978
#   Avg Episode Length: 29.2
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0011
#   Value Loss:   1.8103
#   Entropy:      0.5072
#
# Training Metrics:
#   Grad Norm:    7.488
#   Clip Fraction: 0.043
#   Approx KL:    0.0030
#
# Action Masking:
#   Illegal Before Mask: 0.596
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 82 | Timesteps: 167936/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.474
#   Avg Episode Length: 27.8
#   Episodes Completed: 73
#
# Loss Metrics:
#   Policy Loss:  -0.0005
#   Value Loss:   1.6340
#   Entropy:      0.4875
#
# Training Metrics:
#   Grad Norm:    7.040
#   Clip Fraction: 0.020
#   Approx KL:    0.0035
#
# Action Masking:
#   Illegal Before Mask: 0.596
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 83 | Timesteps: 169984/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.363
#   Avg Episode Length: 27.1
#   Episodes Completed: 75
#
# Loss Metrics:
#   Policy Loss:  0.0004
#   Value Loss:   1.5739
#   Entropy:      0.5161
#
# Training Metrics:
#   Grad Norm:    6.533
#   Clip Fraction: 0.049
#   Approx KL:    0.0068
#
# Action Masking:
#   Illegal Before Mask: 0.624
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 84 | Timesteps: 172032/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.047
#   Avg Episode Length: 29.5
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0019
#   Value Loss:   3.0478
#   Entropy:      0.5215
#
# Training Metrics:
#   Grad Norm:    8.078
#   Clip Fraction: 0.032
#   Approx KL:    0.0032
#
# Action Masking:
#   Illegal Before Mask: 0.571
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 85 | Timesteps: 174080/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.980
#   Avg Episode Length: 29.0
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0008
#   Value Loss:   2.3033
#   Entropy:      0.5404
#
# Training Metrics:
#   Grad Norm:    7.818
#   Clip Fraction: 0.041
#   Approx KL:    0.0050
#
# Action Masking:
#   Illegal Before Mask: 0.589
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 86 | Timesteps: 176128/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 36.673
#   Avg Episode Length: 28.6
#   Episodes Completed: 71
#
# Loss Metrics:
#   Policy Loss:  -0.0001
#   Value Loss:   2.1522
#   Entropy:      0.5132
#
# Training Metrics:
#   Grad Norm:    9.010
#   Clip Fraction: 0.036
#   Approx KL:    0.0037
#
# Action Masking:
#   Illegal Before Mask: 0.583
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 87 | Timesteps: 178176/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.416
#   Avg Episode Length: 29.9
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  -0.0001
#   Value Loss:   1.4065
#   Entropy:      0.4904
#
# Training Metrics:
#   Grad Norm:    7.091
#   Clip Fraction: 0.054
#   Approx KL:    0.0041
#
# Action Masking:
#   Illegal Before Mask: 0.597
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 88 | Timesteps: 180224/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.589
#   Avg Episode Length: 29.7
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  -0.0039
#   Value Loss:   0.9801
#   Entropy:      0.4782
#
# Training Metrics:
#   Grad Norm:    5.597
#   Clip Fraction: 0.077
#   Approx KL:    0.0032
#
# Action Masking:
#   Illegal Before Mask: 0.606
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 89 | Timesteps: 182272/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.444
#   Avg Episode Length: 29.7
#   Episodes Completed: 69
#
# Loss Metrics:
#   Policy Loss:  -0.0002
#   Value Loss:   2.1122
#   Entropy:      0.4960
#
# Training Metrics:
#   Grad Norm:    7.478
#   Clip Fraction: 0.020
#   Approx KL:    0.0023
#
# Action Masking:
#   Illegal Before Mask: 0.599
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 90 | Timesteps: 184320/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 38.081
#   Avg Episode Length: 31.4
#   Episodes Completed: 65
#
# Loss Metrics:
#   Policy Loss:  -0.0008
#   Value Loss:   2.0036
#   Entropy:      0.5288
#
# Training Metrics:
#   Grad Norm:    7.840
#   Clip Fraction: 0.038
#   Approx KL:    0.0057
#
# Action Masking:
#   Illegal Before Mask: 0.607
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 91 | Timesteps: 186368/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.425
#   Avg Episode Length: 30.7
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  -0.0005
#   Value Loss:   3.1700
#   Entropy:      0.5214
#
# Training Metrics:
#   Grad Norm:    9.542
#   Clip Fraction: 0.040
#   Approx KL:    0.0008
#
# Action Masking:
#   Illegal Before Mask: 0.581
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 92 | Timesteps: 188416/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 38.048
#   Avg Episode Length: 31.6
#   Episodes Completed: 64
#
# Loss Metrics:
#   Policy Loss:  0.0015
#   Value Loss:   2.1843
#   Entropy:      0.5390
#
# Training Metrics:
#   Grad Norm:    8.302
#   Clip Fraction: 0.033
#   Approx KL:    0.0030
#
# Action Masking:
#   Illegal Before Mask: 0.583
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 93 | Timesteps: 190464/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.260
#   Avg Episode Length: 30.0
#   Episodes Completed: 68
#
# Loss Metrics:
#   Policy Loss:  -0.0009
#   Value Loss:   1.9633
#   Entropy:      0.5215
#
# Training Metrics:
#   Grad Norm:    8.533
#   Clip Fraction: 0.067
#   Approx KL:    0.0039
#
# Action Masking:
#   Illegal Before Mask: 0.589
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 94 | Timesteps: 192512/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.727
#   Avg Episode Length: 30.7
#   Episodes Completed: 66
#
# Loss Metrics:
#   Policy Loss:  -0.0042
#   Value Loss:   2.2574
#   Entropy:      0.5239
#
# Training Metrics:
#   Grad Norm:    7.847
#   Clip Fraction: 0.097
#   Approx KL:    0.0063
#
# Action Masking:
#   Illegal Before Mask: 0.596
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 95 | Timesteps: 194560/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.919
#   Avg Episode Length: 31.2
#   Episodes Completed: 65
#
# Loss Metrics:
#   Policy Loss:  -0.0028
#   Value Loss:   1.8800
#   Entropy:      0.5364
#
# Training Metrics:
#   Grad Norm:    7.266
#   Clip Fraction: 0.060
#   Approx KL:    0.0034
#
# Action Masking:
#   Illegal Before Mask: 0.605
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 96 | Timesteps: 196608/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 38.060
#   Avg Episode Length: 31.5
#   Episodes Completed: 65
#
# Loss Metrics:
#   Policy Loss:  -0.0003
#   Value Loss:   2.1507
#   Entropy:      0.5202
#
# Training Metrics:
#   Grad Norm:    7.449
#   Clip Fraction: 0.023
#   Approx KL:    0.0013
#
# Action Masking:
#   Illegal Before Mask: 0.600
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 97 | Timesteps: 198656/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.763
#   Avg Episode Length: 32.3
#   Episodes Completed: 63
#
# Loss Metrics:
#   Policy Loss:  -0.0016
#   Value Loss:   4.3001
#   Entropy:      0.5335
#
# Training Metrics:
#   Grad Norm:    9.522
#   Clip Fraction: 0.037
#   Approx KL:    0.0029
#
# Action Masking:
#   Illegal Before Mask: 0.586
#   Illegal After Mask:  0.000
#
# ================================================================================
# Iteration: 98 | Timesteps: 200704/200000
# ================================================================================
# Episode Stats:
#   Avg Episode Reward: 37.108
#   Avg Episode Length: 29.1
#   Episodes Completed: 70
#
# Loss Metrics:
#   Policy Loss:  -0.0023
#   Value Loss:   2.0829
#   Entropy:      0.5068
#
# Training Metrics:
#   Grad Norm:    7.505
#   Clip Fraction: 0.051
#   Approx KL:    0.0031
#
# Action Masking:
#   Illegal Before Mask: 0.563
#   Illegal After Mask:  0.000
#
# ================================================================================
# PPO Training Complete!
# ================================================================================
#
#
# Training completed successfully!
# Final metrics: {'policy_loss': [0.00860988888234715, 0.0015114097477635369, -0.0014513598653138615, -0.0015694962639827281, -0.0041562043625162914, -0.002932430012151599, -0.004510632687015459, -0.004146886807575356, -0.0017973406938835979, -0.0011994542001048103, -0.0036716867543873377, 0.0007049870764603838, 0.001478944999689702, -0.0024901744473027065, -0.0017175034881802276, -0.002671103495231364, 0.00029684053151868284, 0.00016697622777428478, -0.0035746508365264162, 0.0002027279624599032, 0.0011061757541028783, -0.0019135990951326676, -6.860407302156091e-05, -0.0005961378265055828, -0.0007715570391155779, 0.0002882943445001729, -0.0009109665697906166, -0.0015929025685181841, -0.002266339462948963, -0.0009075411799130961, -0.0015205667004920542, -0.0015487934288103133, -0.0003748921153601259, -0.0021000346168875694, -0.0007950155268190429, -0.0002171373926103115, -9.337079245597124e-05, 0.0014660869928775355, -0.0006293629230640363, -0.002054352022241801, -0.0008976599056040868, 0.0014924621500540525, 0.0006405996828107163, -0.00230433457181789, -0.0010622784902807325, -0.003138065949315205, -0.0006907650094944984, 0.0003901933669112623, -0.0022841294048703276, -0.0027936318510910496, 8.748464460950345e-05, -0.0005307153114699759, -0.0014924126517144032, -0.0014345614181365818, 1.5601719496771693e-05, -0.0009504892150289379, -0.0013798583531752229, -0.0027699620768544264, -0.00023074146156432107, -0.00018496509437682107, -0.0011269525311945472, -0.00021059562277514488, -0.0025182504032272846, -0.0014039132365724072, 0.0009925165213644505, -0.0023414485476678237, -0.001146949827671051, -0.0002690405599423684, -0.001360297785140574, -0.0017822870358941145, -0.0013464718504110351, -5.603003955911845e-05, -0.0008274294668808579, -0.002231434569694102, 6.720535748172551e-05, -0.0008938422979554161, -0.0017112730893131811, -0.0011380204305169173, -0.0012390994161251, -0.0014388421113835648, -0.001121146917284932, -0.0004671399656217545, 0.0003977885207859799, -0.0018542027537478134, -0.0008052153207245283, -8.22926958790049e-05, -0.00014695570280309767, -0.003910744417225942, -0.00018650386482477188, -0.0007657035603187978, -0.0004837938759010285, 0.001505424384959042, -0.0009395602828590199, -0.004205709454254247, -0.0028498729079728946, -0.0003245199768571183, -0.001572883327753516, -0.0023172859073383734], 'value_loss': [63.88117700815201, 23.083285316824913, 11.027726894244552, 5.804433880373836, 4.293690886348486, 3.575195936486125, 3.1078658681362867, 3.5134256137534976, 3.8693261006847024, 2.56661031069234, 3.7203801004216075, 2.6748429015278816, 3.5495053119957447, 3.2403514618054032, 3.6893527880311012, 3.828944061882794, 3.8345910934731364, 2.9984307773411274, 4.635204523801804, 2.223671675659716, 4.641386264935136, 3.487789428792894, 3.2495323922485113, 2.3960948595777154, 3.0418893778696656, 3.067578391171992, 2.8995778309181333, 3.937998127192259, 3.5978379463776946, 2.2900147032923996, 4.0893414644524455, 3.5819004429504275, 1.8315447508357465, 2.5737424278631806, 3.21984491776675, 2.11374060343951, 3.0281607499346137, 2.0123431738466024, 2.7468398921191692, 2.375688544008881, 1.3247819016687572, 2.4193578958511353, 1.853015701752156, 2.5130609022453427, 1.7748558432795107, 1.6978985499590635, 1.286989473272115, 1.2170637315139174, 1.2272513543721288, 2.0095014167018235, 1.9125519515946507, 2.246366779319942, 1.6698465589433908, 1.8002280672080815, 1.4008570807054639, 2.416638313792646, 1.658854940906167, 1.4945423025637865, 2.068642843514681, 0.8794407255481929, 3.0099087744019926, 1.5871926681138575, 1.8672932744957507, 2.1768813095986843, 1.617705951211974, 2.2224102914333344, 0.7547417406458408, 2.6285173655487597, 2.051859302446246, 2.137707161484286, 1.076016082195565, 2.304924565833062, 2.499110641889274, 2.5146461818367243, 1.8864486804232001, 2.1147682713344693, 2.189775229431689, 1.516966057009995, 3.0592933297157288, 1.5814803619869053, 1.8103034254163504, 1.6339635802432895, 1.573859530268237, 3.047754 ...

# %%
GameHelper.play_against_model(model=ppo_model, game=game, mode='ppo')
# Out:
# Game started!
#       [4] [4] [4] [4] [4] [4]
# [0]                             [0]
#       [4] [4] [4] [4] [4] [4]
#
# Playable moves: [0, 1, 2, 3, 4, 5]
# Your move: 1
#       [4] [4] [4] [4] [4] [4]
# [0]                             [0]
#       [4] [0] [5] [5] [5] [5]
#
# Playable moves: [7, 8, 9, 10, 11, 12]
# Model's move: 2
#       [5] [5] [5] [0] [4] [4]
# [1]                             [0]
#       [4] [0] [5] [5] [5] [5]
#
# Playable moves: [7, 8, 10, 11, 12]
# Model's move: 0
#       [5] [6] [6] [1] [5] [0]
# [1]                             [0]
#       [4] [0] [5] [5] [5] [5]
#
# Playable moves: [0, 2, 3, 4, 5]
# Your move: 5
#       [5] [6] [7] [2] [6] [1]
# [1]                             [1]
#       [4] [0] [5] [5] [5] [0]
#
# Playable moves: [7, 8, 9, 10, 11, 12]
# Model's move: 2
#       [5] [7] [8] [0] [6] [1]
# [1]                             [1]
#       [4] [0] [5] [5] [5] [0]
#
# Playable moves: [0, 2, 3, 4]
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
# Please enter a valid number.
