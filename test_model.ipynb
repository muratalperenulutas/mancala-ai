# %%
from model_helper import ModelHelper
from game_helper import GameHelper
from game.game import Game
# Out:
# 2025-10-27 06:28:31.742582: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model=ModelHelper.load_model('mancala_model_iter_1876.keras')
model.summary()
# Out:
# Model loaded from mancala_model_iter_1876.keras.
# 2025-10-27 06:28:33.930563: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ state (InputLayer)  │ (None, 20)        │          0 │ -                 │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared1 (Dense)     │ (None, 128)       │      2,688 │ state[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ shared2 (Dense)     │ (None, 128)       │     16,512 │ shared1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ logits (Dense)      │ (None, 6)         │        774 │ shared2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ value (Dense)       │ (None, 1)         │        129 │ shared2[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 20,103 (78.53 KB)
#  Trainable params: 20,103 (78.53 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
game=Game()
game.initialize()

# %%
GameHelper.play_against_model(model=model, game=game)
# Out:
# Game started!
#       [4] [4] [4] [4] [4] [4]
# [0]                             [0]
#       [4] [4] [4] [4] [4] [4]
#
# Playable moves: [0, 1, 2, 3, 4, 5]
# Your move: 5
#       [4] [4] [4] [5] [5] [5]
# [0]                             [1]
#       [4] [4] [4] [4] [4] [0]
#
# Playable moves: [7, 8, 9, 10, 11, 12]
# Logits: [[ 21.021238  -11.619376   38.368145   -1.4251035  29.034359   31.761057 ]]
# Q-values: [ 21.021238  -11.619376   38.368145   -1.4251035  29.034359   31.761057 ]
# Model's move: 2
#       [5] [5] [5] [0] [5] [5]
# [1]                             [1]
#       [5] [4] [4] [4] [4] [0]
#
# Playable moves: [0, 1, 2, 3, 4]
# Your move: 2
#       [5] [5] [5] [0] [5] [5]
# [1]                             [2]
#       [5] [4] [0] [5] [5] [1]
#
# Playable moves: [0, 1, 3, 4, 5]
